# %%
import pandas as pd

# %%
customerData=pd.read_csv("../dataset/kopo_customerdata.csv0")
customerTotalList=customerData["TOTAL_AMOUNT"].tolist()

# %%
print(customerTotalList)
# Out:
# [30300, 46500, 22700, 31400, 44900, 38300, 19900, 14800, 24400, 30400, 30300, 34300, 14900, 16300, 25000, 27500, 18200, 40200, 74600, 42700, 14900, 58700, 16000, 17800, 26800, 14000, 31800, 16000, 37600, 32800, 176600, 16200, 102000, 56800, 14700, 14800, 2500, 23600, 38100, 82300, 62900, 5000, 16100, 40900, 14600, 28600, 12300, 37800, 32600, 16100, 18400, 17700, 9400, 37400, 8800, 26600, 20900, 15800, 14800, 20500, 19700, 39900, 122900, 33000, 12100, 14700, 48400, 51900, 17400, 26500, 12800, 15500, 21400, 15300, 36000, 49000, 35800, 16900, 43000, 28200, 45100, 18200, 20600, 23900, 14500, 70000, 15800, 6600, 40500, 17000, 43800, 146800, 86900, 19200, 17100, 18800, 24700, 17500, 25100, 19000, 18800, 55700, 31500, 27800, 16000, 14100, 17100, 20600, 19100, 14500, 29400, 17700, 54400, 13100, 33700, 17600, 29000, 41300, 27700, 25900, 21900, 41100, 15000, 67100, 29600, 13900, 21700, 15200, 13100, 25600, 12500, 18600, 30700, 23000, 41400, 29400, 40400, 50600, 34700, 12800, 26300, 14900, 1450
# ...

# %%
print(len(customerTotalList))
# Out:
# 300000

# %%
maxcus=max(customerTotalList)
mincus=min(customerTotalList)

maxcus2 = customerTotalList.remove(maxcus)
mincus2 = customerTotalList.remove(mincus)

sumcus = sum(customerTotalList)
lencus = len(customerTotalList)

print(len(customerTotalList))
# Out:
# 299998

# %%
Average= sumcus / lencus
print(Average)
# Out:
# 35218.95312635417
